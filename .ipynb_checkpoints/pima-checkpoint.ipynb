# %%
#intalando paquetes 
# %pip install pandas
# %pip install seaborn

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Cargamos los datos

# %%
db = pd.read_csv("pima-indians-diabetes.csv", skiprows=2, header=0, low_memory=False, na_values=['', ' ', 'NA', 'N/A', '-'])

# %% [markdown]
# Revisamos las primeras filas

# %%
db.head(10)
# Out:
#     8  183  64   0  0.1  23.3  0.672  Unnamed: 7  1
# 0   1   89  66  23   94  28.1  0.167          21  0
# 1   0  137  40  35  168  43.1  2.288          33  1
# 2   5  116  74   0    0  25.6  0.201          30  0
# 3   3   78  50  32   88  31.0  0.248          26  1
# 4  10  115   0   0    0  35.3  0.134          29  0
# 5   2  197  70  45  543  30.5  0.158          53  1
# 6   8  125  96   0    0   0.0  0.232          54  1
# 7   4  110  92   0    0  37.6  0.191          30  0
# 8  10  168  74   0    0  38.0  0.537          34  1
# 9  10  139  80   0    0  27.1  1.441          57  0

# %% [markdown]
# Podemos observar que no se dispone de un nombre de columna para facilitar el tratamiento del dataset por ello utilizaremos los siguientes atributos brindados en la información para colocar un nombre a nuestras columnas
#
# 1. Number of times pregnant
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3. Diastolic blood pressure (mm Hg)
# 4. Triceps skin fold thickness (mm)
# 5. 2-Hour serum insulin (mu U/ml)
# 6. Body mass index (weight in kg/(height in m)^2)
# 7. Diabetes pedigree function
# 8. Age (years)
# 9. Class variable
#
# Usamos el prámetro 'names' para agregar el nombre de colummnas

# %%
column_names =[ 'timesPregnant','glucose','preasure','thickness','insulin','mass','pedigree','age','clase']
db = pd.read_csv("pima-indians-diabetes.csv", skiprows=2, names = column_names, header=0, low_memory=False)

# %% [markdown]
# También podemos hacerlo de la siguiente forma

# %%
db.columns = [ 'timesPregnant','glucose','preasure','thickness','insulin','mass','pedigree','age','clase']

# %% [markdown]
# Ahora comprobamos que ya lo tenemos mas organizados

# %%
db.head(10)
# Out:
#    timesPregnant  glucose  preasure  thickness  insulin  mass  pedigree  age  \
# 0              1       89        66         23       94  28.1     0.167   21
# 1              0      137        40         35      168  43.1     2.288   33
# 2              5      116        74          0        0  25.6     0.201   30
# 3              3       78        50         32       88  31.0     0.248   26
# 4             10      115         0          0        0  35.3     0.134   29
# 5              2      197        70         45      543  30.5     0.158   53
# 6              8      125        96          0        0   0.0     0.232   54
# 7              4      110        92          0        0  37.6     0.191   30
# 8             10      168        74          0        0  38.0     0.537   34
# 9             10      139        80          0        0  27.1     1.441   57
#
#    clase
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
# 5      1
# 6      1
# 7      0
# 8      1
# 9      0

# %% [markdown]
# Comprobamos la dimensión del Dataframe

# %%
db.shape
# Out:
# (765, 9)

# %% [markdown]
# Comprobamos la información del Dataframe

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timesPregnant  765 non-null    int64
#  1   glucose        765 non-null    int64
#  2   preasure       765 non-null    int64
#  3   thickness      765 non-null    int64
#  4   insulin        765 non-null    int64
#  5   mass           765 non-null    float64
#  6   pedigree       765 non-null    float64
#  7   age            765 non-null    int64
#  8   clase          765 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 53.9 KB

# %% [markdown]
# Comprobamos valores faltantes

# %%
db.isnull().sum()

# sns.heatmap(db.isna(), cbar=False, cmap='viridis')
# plt.title('Valores Faltantes en el Dataset')
# plt.show()
# Out:
# timesPregnant    0
# glucose          0
# preasure         0
# thickness        0
# insulin          0
# mass             0
# pedigree         0
# age              0
# clase            0
# dtype: int64

# %% [markdown]
# Ahora prosedesmoa al alimpieza de datos
# 1. Eliminamos eventos Columnas/filas del resumen
# 2. unimos eventuales columnas para entender mejor lo datos
# 3. de igual forma devidimos eventuales columnas
# 4. ...

# %% [markdown]
# Manejo de valores de valores faltantes
# -
# Existen 3 tipos:
# - MCAR
# - MAR
# - MNAR

# %%
db = db[~db.age.isnull().copy()]
db.isnull().sum()
db.shape
# Out:
# (765, 9)

# %% [markdown]
# - 'imputar' proceso de reemplazar los valores faltantes en uun conjunto de datos con valores sustitutos
# - La imputación es una tecnica utilizafa para manejar datos incompletos , situación común en un problema real
# - En esta práctica vamos a imputar valores para los meses

# %%
counts = db['clase'].value_counts()

# Graficar las frecuencias
counts.plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de cada clase')
plt.show()

# %%
counts = db['clase'].value_counts()

# Graficar un pie chart
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['blue', 'orange'])
plt.title('Distribución de clases')
plt.show()

# %% [markdown]
# db ['month'] = db['monyh'].fillna(month_mode, inplace = true)

# %%
db ['month'] = db['month'].fillna(month_mode) 
db.month.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[266], line 1
# ----> 1 db ['month'] = db['month'].fillna(month_mode)
#       2 db.month.isnull().sum()
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'month'

# %%
db.shape
# Out:
# (45191, 20)

# %% [markdown]
# Nota: podemos sustituir lods valores falatantes con NaN

# %% [markdown]
# # OUTLIERS
# Los outliers (dato atípico) es un dato que se diferencia sifgnificativamente de otros valores y del conjunto de datos.
# Surgen por:
# - Variabilidad natural
# - Error en la recopilación
# - Es un indicador de eventos inusuales
#
# Tipos de outliers
# - Outlier univariado
# - Outlier multivariado/bivariado, cuando ploteamos una variable con otra se desvía el valor esperado de manera anormal
#
# ## Análisis univariado de variable categórica no ordenada
# * No tienen peso o medida
# * No tienen orden

# %%
db.job.value_counts()
# Out:
# job
# blue-collar      9727
# management       9455
# technician       7594
# admin.           5170
# services         4152
# retired          2263
# self-employed    1578
# entrepreneur     1485
# unemployed       1302
# housemaid        1239
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
db.job.value_counts(normalize=True)
# Out:
# job
# blue-collar      0.215242
# management       0.209223
# technician       0.168042
# admin.           0.114403
# services         0.091877
# retired          0.050076
# self-employed    0.034918
# entrepreneur     0.032861
# unemployed       0.028811
# housemaid        0.027417
# student          0.020756
# unknown          0.006373
# Name: proportion, dtype: float64

# %%
db.job.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# ## Análisis univariado de una variable categórica ordena
# Estas variables tienen n orden natural, por ejemplo:
# - mese
# educación

# %%
db.clase.value_counts(normalize=True).plot.pie()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8488\3392228003.py in ?()
# ----> 1 db.clase.value_counts(normalize=True).plot.pie()
#       2 plt.show()
#
# c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'clase'

# %% [markdown]
# si tenempos variables con valores numériicos, podemos calcular lo siguiente:

# %%
db.timesPregnant.describe()
# Out:
# count    765.000000
# mean       3.840523
# std        3.370364
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: timesPregnant, dtype: float64

# %% [markdown]
# Finalmente podemos plotear una densidad de la distribución de la variable numérica

# %%
sns.displot(db['salary'], kde = True)
plt.xlabel('Salary')
plt.ylabel('Frecuency')
plt.title('Distribución del Salario')
plt.show()

# %%
sns.displot(db['timesPregnant'])
# Out:
# c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(db['class'])
# Out:
# c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
db.balance.describe()
# Out:
# count     45191.000000
# mean       1362.432520
# std        3045.120417
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
sns.histplot(db['balance'])
plt.xlim(-8019, 102127)
plt.ylim(0, 3000)
plt.show()

# %% [markdown]
# ## Analisis bivariado
# Es un analisis de este tipo es util el uso de gráficos, en particular:
# - scatter plot
# - pair plot
# - matriz de correlacion

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(db.salary, db.balance)

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(data = db, vars = ['salary', 'balance', 'edad'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'edad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 sns.pairplot(data = db, vars = ['salary', 'balance', 'edad'])
#       2 plt.show()
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:2149, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2147 diag_kws.setdefault("legend", False)
#    2148 if diag_kind == "hist":
# -> 2149     grid.map_diag(histplot, **diag_kws)
#    2150 elif diag_kind == "kde":
#    2151     diag_kws.setdefault("fill", True)
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1496, in PairGrid.map_diag(self, func, **kwargs)
#    1493 else:
#    1494     plt.sca(ax)
# -> 1496 vector = self.data[var]
#    1497 if self._hue_var is not None:
#    1498     hue = self.data[self._hue_var]
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'edad'

# %% [markdown]
# ## QQ - Plot
#
# Es un método grafico para el diagnostico de diferencias entre la distribucion de probabilidad de una poblacion que se ha extraido una muestra aleatoria y una distribucion  usada para la comparacion

# %%
# %pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\14\appdata\local\programs\python\python312\lib\site-packages (1.14.0)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\14\appdata\local\programs\python\python312\lib\site-packages (from scipy) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scipy.stats as stats
iris = sns.load_dataset('iris')

rvs = stats.norm(loc =0, scale =1)
normal_sample = rvs.rvs(size = 100000)
sns.set()
sns.displot(normal_sample)

# %%
normal_sample = rvs.rvs(size=100000)
stats.probplot(normal_sample, dist='norm')

# %% [markdown]
# # Matriz de correlación
# Es un gráfico que nos permite identificar las relaciones entre mas de una variable de forma sintetica

# %%
sns.heatmap(db[['age','salary','balance']].corr(), annot=True, cmap = 'Blues')
plt.show()

# %%
numerica_sf = db.select_dtypes(include =['number'])
sns.heatmap(numerica_sf.corr(), annot=True, cmap = 'Blues')
plt.show()

# %% [markdown]
# # Variables categóricas numéricas
# Normalmente se analizan con base a su media, mediana y un instrumento muy utilizado es el bloxpot

# %%
db.groupby('response')['salary'].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
db.groupby('response')['salary'].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
sns.boxplot (x=db.response, y=db.salary)
plt.show()

# %% [markdown]
# # Abalisis de variables categóricas
# Queremos analizar como diferentes variables categóricas (education) tienen impacto en la variable independiente.
# Para hacer esto necesitamos convertir response en una varible binaria

# %%
db['response_rate'] = np.where(db.response =='yes', 1,0)
db.response_rate.value_counts()
# Out:
# response_rate
# 0    39906
# 1     5285
# Name: count, dtype: int64

# %% [markdown]
# Analizando ahora como se distribuye frente a distintos valores de variable categórica, tenemos:

# %%
db.groupby('marital')['response_rate'].mean().plot.bar()
plt.show()

# %% [markdown]
# # Analisis multivariable
# Como ejmeplo vamos a crear una tabla pivot con las columnas dde los diferentes estados civiles

# %%
result = pd.pivot_table(data = db, index = 'education', columns ='marital', values ='response_rate')
result
# Out:
# marital    divorced   married    single
# education
# primary    0.138667  0.075515  0.106808
# secondary  0.103485  0.094595  0.129213
# tertiary   0.137415  0.129761  0.183546
# unknown    0.142012  0.122414  0.162879

# %%
sns.heatmap(result, annot = True, cmap='RdY1Gn', center=0.117)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 sns.heatmap(result, annot = True, cmap='RdY1Gn', center=0.117)
#       2 plt.show()
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:217, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     215         self.cmap = cm.icefire
#     216 elif isinstance(cmap, str):
# --> 217     self.cmap = get_colormap(cmap)
#     218 elif isinstance(cmap, list):
#     219     self.cmap = mpl.colors.ListedColormap(cmap)
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_compat.py:62, in get_colormap(name)
#      60 """Handle changes to matplotlib colormap interface in 3.6."""
#      61 try:
# ---> 62     return mpl.colormaps[name]
#      63 except AttributeError:
#      64     return mpl.cm.get_cmap(name)
#
# File c:\Users\14\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\cm.py:91, in ColormapRegistry.__getitem__(self, item)
#      89     return self._cmaps[item].copy()
#      90 except KeyError:
# ---> 91     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'RdY1Gn' is not a known colormap name"
